# %% [markdown]
# ### Q1. What is Ridge Regression, and how does it differ from ordinary least squares regression?

# %% [markdown]
# Ridge Regression is a type of linear regression that adds a penalty term to the ordinary least squares regression.This penalty term shrinks the coefficients of the regression model, reducing the impact of less important predictors and improving model performance in situations where there are many predictors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q2. What are the assumptions of Ridge Regression?

# %% [markdown]
# Ridge regression assumes that the relationship between the dependent variable and independent variables is linear, and that the errors and have constant variance. Additionally, it assumes that the independent variables are not highly correlated with each other.

# %% [markdown]
# ### Q3. How do you select the value of the tuning parameter (lambda) in Ridge Regression?

# %% [markdown]
# The value of the tuning parameter (lambda) in Ridge Regression is typically chosen using cross-validation. The data is split into several subsets, and the model is trained on each subset while being evaluated on the remaining data. The value of lambda that results in the best overall performance is chosen.

# %% [markdown]
# ### Q4. Can Ridge Regression be used for feature selection? If yes, how?

# %% [markdown]
# Ridge regression can't perform feature selection, unlike Lasso regression. Ridge regression shrinks the coefficients of all variables towards zero, but it doesn't set any coefficients to exactly zero. Thus, all variables contribute to the model to some extent, and Ridge regression is used when all variables are thought to be important.

# %% [markdown]
# ### Q5. How does the Ridge Regression model perform in the presence of multicollinearity?

# %% [markdown]
# Ridge regression is designed to handle multicollinearity, which is a situation where two or more independent variables are highly correlated with each other. The Ridge regression model adds a penalty term to the loss function, which shrinks the regression coefficients towards zero.
# This helps to reduce the impact of multicollinearity on the model's performance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q6. Can Ridge Regression handle both categorical and continuous independent variables?

# %% [markdown]
# Yes, Ridge Regression can handle both categorical and continuous independent variables. In Ridge Regression, all variables are treated equally, and the regularization penalty is applied to all variables regardless of their type. Therefore, the model can handle a mix of categorical and continuous variables.

# %% [markdown]
# ### Q7. How do you interpret the coefficients of Ridge Regression?

# %% [markdown]
# The coefficients of Ridge Regression represent the change in the dependent variable for each unit change in the independent variable while controlling for other variables. However, unlike in linear regression, the coefficients in Ridge Regression are shrunk towards zero to reduce overfitting. Thus, the magnitude of the coefficients should be interpreted in relation to the value of the regularization parameter used in the model.

# %% [markdown]
# ### Q8. Can Ridge Regression be used for time-series data analysis? If yes, how?

# %% [markdown]
# Yes, Ridge Regression can be used for time-series data analysis. It can be used to reduce the effects of multicollinearity and improve the accuracy of predictions.
# The regularization parameter can be tuned to balance the trade-off between bias and variance.
